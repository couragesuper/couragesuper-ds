# %%
import sys
import time
sys.path.append("../Common/Crawler")
sys.path.append("../Common/Util")

import mod_crawler_base as craw

isLinux = True
isHidden = True

from time import sleep

wd = craw.InitWebDriver( isLinux, isHidden )
# Out:
# [MSG][Load Crawler Base Component]

# %%
from Util import stopWatch 

swatch = stopWatch()

# %%
swatch.reset()
craw.OpenWebPage(wd, "http://news.joins.com/article/406324" ,1)
swatch.diff()
# Out:
# difference : 16 sec

# %%
elem = wd.find_element_by_class_name('byline')
print( elem.text.split())

pos1 = elem.text.find("입력")
pos2 = elem.text.find("수정")
pos3 = elem.text.find("야후")

print( pos1, pos2, pos3 )

txt = elem.text

pos1 = elem.text.find("입력")
if( pos2 != -1 ) : txt = txt[pos1 + 2: pos2].strip().split()[0]
else : txt = txt[pos1 + 2:pos1+2 ].strip().split()[0]

print( txt )
# Out:
# ['[중앙일보]', '입력', '2004.10.28', '18:26', '수정', '2004.10.29', '09:13', '|', '종합', '35면', '지면보기']
# 7 27 -1
# 2004.10.28

# %%
delay_sleep = 10

def crawler_joongang_bunsudae_withPage( page_start , page_end ) :
    now = time.localtime()
    time_str = "%04d%02d%02d_%02d%02d%02d_from%d_to%d" % ( now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec , page_start, page_end )
    with open(  "joongang_opnion_bunsudae_" + time_str + ".txt" , "w+" , encoding='utf-8' ) as f:
        for i in range(page_start,page_end) :
            print(i)
            baseUrl = "http://news.joins.com/find/list?page=%d&IsDuplicate=True&key=EditorialColumn&Display=분수&Keyword=분수대&SourceGroupType=Joongang&ServiceCode=20" % (i)
            craw.OpenWebPage(wd, baseUrl ,1)
            
            listLink = []
            listElem = wd.find_elements_by_class_name( 'headline' ) 
            for i,elem in enumerate( listElem ) :
                listLink.append( elem.find_element_by_tag_name('a').get_attribute('href') )

            for i,elem in enumerate( listLink ) :        
                craw.OpenWebPage(wd, listLink[i] ,1)
                elem = wd.find_element_by_class_name( 'article_body' )
                txt_org = elem.text
                txt_proc = txt_org.replace("\n","  ")
                print( txt_proc )
                f.write( txt_proc )
                f.write("\n")       
            sleep(delay_sleep)

# %%
# %%time
crawler_joongang_bunsudae_withPage( 1, 2 )
# Out:
# 1
# ...

# %%
swatch.reset()
craw.OpenWebPage(wd, "https://news.joins.com/article/22644220" ,1)
swatch.diff()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-9-51809da076e8> in <module>()
#       1 swatch.reset()
# ----> 2 craw.OpenWebPage(wd, "https://news.joins.com/article/22644220" ,1)
#       3 swatch.diff()
#
# ~/Python/couragesuper-ds/Common/Crawler/mod_crawler_base.py in OpenWebPage(webDrv, URL, delay)
#      33 #   open the web page
#      34 def OpenWebPage(webDrv, URL, delay=2.0):
# ---> 35     webDrv.get(URL)
#      36     webDrv.implicitly_wait(delay)
#      37
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     330         Loads a web page in the current browser session.
#     331         """
# --> 332         self.execute(Command.GET, {'url': url})
#     333
#     334     @property
#
# ...

# %%
elem = wd.find_element_by_class_name('tag_list')
# Out:
# ---------------------------------------------------------------------------
# CannotSendRequest                         Traceback (most recent call last)
# <ipython-input-8-bb553eb1f5af> in <module>()
# ----> 1 elem = wd.find_element_by_class_name('tag_list')
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     561             element = driver.find_element_by_class_name('foo')
#     562         """
# --> 563         return self.find_element(by=By.CLASS_NAME, value=name)
#     564
#     565     def find_elements_by_class_name(self, name):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# ...

# %%
listTags = elem.text.split("#")[1:]
szTags = ""
for tags in listTags : 
    szTags += tags.replace("\n","")
    szTags += "|"
print(szTags )
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-10-4902bd34f5e5> in <module>()
# ----> 1 listTags = elem.text.split("#")[1:]
#       2 szTags = ""
#       3 for tags in listTags :
#       4     szTags += tags.replace("\n","")
#       5     szTags += "|"
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
# ...
