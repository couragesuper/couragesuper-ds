# %%
import mysql.connector

class dbConMysql:
    def __init__(self , dictConfig ) :
        self.con = mysql.connector.connect( **dictConfig )
    def commitQuery(self, szQry):
        self.cursor = self.con.cursor(buffered = True)
        self.cursor.execute(szQry) 
        self.cursor.close()        
        self.con.commit()
    def selectQuery(self,szQry):
        self.cursor = self.con.cursor(buffered = True)
        self.cursor.execute(szQry)
        listRet = [ { self.cursor.description[i][0]:elem  for i,elem in enumerate(row)} for row in self.cursor ]
        self.cursor.close()
        return listRet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cb70e45b797c> in <module>()
# ----> 1 import mysql.connector
#       2
#       3 class dbConMysql:
#       4     def __init__(self , dictConfig ) :
#       5         self.con = mysql.connector.connect( **dictConfig )
#
# ModuleNotFoundError: No module named 'mysql'

# %%
config = {
  'user': 'root',
  'password': 'karisma*3%7*4',
  'host': 'mthx.cafe24.com',
  'database': 'bible',
  'raise_on_warnings': True,
}

dbbible = dbConMysql(config)

query = "select * from TB_BIBLE"
ret = dbbible.selectQuery( query )
print( ret )

query = "SELECT "\
" (SELECT BOOK_KOR_SUMNM FROM TB_BIBLE_BOOK WHERE BOOK_SEQNO = TBA.BOOK_SEQNO) AS BOOK_NM,"\
" BOOK_SEQNO AS SEQNO,"\
" BOOK_CHAP_NO AS CHAPNO,"\
" BOOK_NO AS NO,"\
" BOOK_CONTENT AS CONTENT "\
" FROM TB_BIBLE_BOOK_DATA TBA WHERE BOOK_CONTENT like \"%%%s%%\" " % ("요한")
ret = dbbible.selectQuery( query )
print( ret )
# Out:
# [{'BIBLE_SEQNO': 1, 'BIBLE_NAME': 'NLTOLD', 'BIBLE_DESC': 'NLT성경 신약데이터'}, {'BIBLE_SEQNO': 2, 'BIBLE_NAME': 'NLTNEW', 'BIBLE_DESC': 'NLT성경 구약데이터'}, {'BIBLE_SEQNO': 3, 'BIBLE_NAME': 'KOROLD', 'BIBLE_DESC': '개역개정 구약데이터'}, {'BIBLE_SEQNO': 4, 'BIBLE_NAME': 'KORNEW', 'BIBLE_DESC': '개역개정 신약데이터'}]
# [{'BOOK_NM': '신', 'SEQNO': 5, 'CHAPNO': 15, 'NO': 8, 'CONTENT': '반드시 네 손을 그에게 펴서 그에게 필요한 대로 쓸 것을 넉넉히 꾸어주라 '}, {'BOOK_NM': '왕상', 'SEQNO': 11, 'CHAPNO': 8, 'NO': 59, 'CONTENT': '여호와 앞에서 내가 간구한 이 말씀이 주야로 우리 하나님 여호와께 가까이 있게 하시옵고 또 주의 종의 일과 주의 백성 이스라엘의 일을 날마다 필요한 대로 돌아보사 '}, {'BOOK_NM': '대상', 'SEQNO': 13, 'CHAPNO': 9, 'NO': 26, 'CONTENT': '이는 문지기의 우두머리 된 레위 사람 넷이 중요한 직분을 맡아 하나님의 성전 모든 방과 곳간을 지켰음이라 '}, {'BOOK_NM': '잠', 'SEQNO': 20, 'CHAPNO': 14, 'NO': 20, 'CONTENT': '가난한 자는 이웃에게도 미움을 받게 되나 부요한 자는 친구가 많으니라 '}, {'BOOK_NM': '잠', 'SEQNO': 20, 'CHAPNO': 30, 'NO': 8, 'CONTENT': '곧 헛된 것과 거짓말을 내게서 멀리 하옵시며 나를 가난하게도 마옵시고 부하게도 마옵시고 오직 필요한 양식으로 나를 먹이시옵소서 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 3, 'NO': 1, 'CONTENT': '그 때에 세례 요한이 이르러 유대 광야에서 전파하여 말하되 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 3, 'NO': 4, 'CONTENT': '이 요한은 낙타털 옷을 입고 허리에 가죽 띠를 띠고 음식은 메뚜기와 석청이었더라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 3, 'NO': 7, 'CONTENT': '요한이 많은 바리새인들과 사두개인들이 세례 베푸는 데로 오는 것을 보고 이르되 독사의 자식들아 누가 너희를 가르쳐 임박한 진노를 피하라 하더냐 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 3, 'NO': 13, 'CONTENT': '이 때에 예수께서 갈릴리로부터 요단 강에 이르러 요한에게 세례를 받으려 하시니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 3, 'NO': 14, 'CONTENT': '요한이 말려 이르되 내가 당신에게서 세례를 받아야 할 터인데 당신이 내게로 오시나이까 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 3, 'NO': 15, 'CONTENT': '예수께서 대답하여 이르시되 이제 허락하라 우리가 이와 같이 하여 모든 의를 이루는 것이 합당하니라 하시니 이에 요한이 허락하는지라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 4, 'NO': 12, 'CONTENT': '예수께서 요한이 잡혔음을 들으시고 갈릴리로 물러가셨다가 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 4, 'NO': 21, 'CONTENT': '거기서 더 가시다가 다른 두 형제 곧 세베대의 아들 야고보와 그의 형제 요한이 그의 아버지 세베대와 함께 배에서 그물 깁는 것을 보시고 부르시니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 9, 'NO': 14, 'CONTENT': '그 때에 요한의 제자들이 예수께 나아와 이르되 우리와 바리새인들은 금식하는데 어찌하여 당신의 제자들은 금식하지 아니하나이까 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 10, 'NO': 2, 'CONTENT': '열두 사도의 이름은 이러하니 베드로라 하는 시몬을 비롯하여 그의 형제 안드레와 세베대의 아들 야고보와 그의 형제 요한, '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 2, 'CONTENT': '요한이 옥에서 그리스도께서 하신 일을 듣고 제자들을 보내어 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 4, 'CONTENT': '예수께서 대답하여 이르시되 너희가 가서 듣고 보는 것을 요한에게 알리되 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 7, 'CONTENT': '그들이 떠나매 예수께서 무리에게 요한에 대하여 말씀하시되 너희가 무엇을 보려고 광야에 나갔더냐 바람에 흔들리는 갈대냐 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 11, 'CONTENT': '내가 진실로 너희에게 말하노니 여자가 낳은 자 중에 세례 요한보다 큰 이가 일어남이 없도다 그러나 천국에서는 극히 작은 자라도 그보다 크니라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 12, 'CONTENT': '세례 요한의 때부터 지금까지 천국은 침노를 당하나니 침노하는 자는 빼앗느니라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 13, 'CONTENT': '모든 선지자와 율법이 예언한 것은 요한까지니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 11, 'NO': 18, 'CONTENT': '요한이 와서 먹지도 않고 마시지도 아니하매 그들이 말하기를 귀신이 들렸다 하더니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 2, 'CONTENT': '그 신하들에게 이르되 이는 세례 요한이라 그가 죽은 자 가운데서 살아났으니 그러므로 이런 능력이 그 속에서 역사하는도다 하더라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 3, 'CONTENT': '전에 헤롯이 그 동생 빌립의 아내 헤로디아의 일로 요한을 잡아 결박하여 옥에 가두었으니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 4, 'CONTENT': '이는 요한이 헤롯에게 말하되 당신이 그 여자를 차지한 것이 옳지 않다 하였음이라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 5, 'CONTENT': '헤롯이 요한을 죽이려 하되 무리가 그를 선지자로 여기므로 그들을 두려워하더니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 8, 'CONTENT': '그가 제 어머니의 시킴을 듣고 이르되 세례 요한의 머리를 소반에 얹어 여기서 내게 주소서 하니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 10, 'CONTENT': '사람을 보내어 옥에서 요한의 목을 베어 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 14, 'NO': 12, 'CONTENT': '요한의 제자들이 와서 시체를 가져다가 장사하고 가서 예수께 아뢰니라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 16, 'NO': 14, 'CONTENT': '이르되 더러는 세례 요한, 더러는 엘리야, 어떤 이는 예레미야나 선지자 중의 하나라 하나이다 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 17, 'NO': 1, 'CONTENT': '엿새 후에 예수께서 베드로와 야고보와 그 형제 요한을 데리시고 따로 높은 산에 올라가셨더니 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 17, 'NO': 13, 'CONTENT': '그제서야 제자들이 예수께서 말씀하신 것이 세례 요한인 줄을 깨달으니라 '}, {'BOOK_NM': '마', 'SEQNO': 40, 'CHAPNO': 21, 'NO': 25, 'CONTENT': '요한의 세례가 어디로부터 왔느냐 하늘로부터냐 사람으로부터냐 그들이 서로 의논하여 이르되 만일  ...
