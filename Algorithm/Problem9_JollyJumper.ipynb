# %%
import random 

isJolly = False  

while( isJolly == False ) :
    randlist = [random.randrange(1,10) for i in range(10)] 
    #randlist = [1,4,2,3] # true 
    ret_list = [] 
    for i in range(0,len(randlist) - 1) : 
        abs_diff = abs(randlist[i] - randlist[i + 1]) 
        print( abs_diff ) 
        ret_list.append( abs_diff ) 

    ret_list.sort() 
    print( ret_list ) 
    firstJolly = 1 
    lastJolly = len(randlist) - 1 
    isJolly = True
    if( (ret_list[0] != 1) or 
        (ret_list[ len(ret_list)-1 ] != lastJolly ) ) : isJolly = False 
    if ( isJolly == True ): 
        for i in range(0,len(ret_list) - 1) : 
            if( (ret_list[i+1] - ret_list[i]) != 1 ) : 
                isJolly = False 
                break 

    print( isJolly )
# Out:
# 3
# 1
# 1
# 4
# 3
# 1
# 4
# 2
# 5
# [1, 1, 1, 2, 3, 3, 4, 4, 5]
# False
# 1
# 0
# 4
# 4
# 5
# 3
# 2
# 1
# 1
# [0, 1, 1, 1, 2, 3, 4, 4, 5]
# False
# 6
# 2
# 2
# 1
# 3
# 5
# 5
# 1
# 3
# [1, 1, 2, 2, 3, 3, 5, 5, 6]
# False
# 0
# 2
# 5
# 0
# 7
# 5
# 1
# 3
# 2
# [0, 0, 1, 2, 2, 3, 5, 5, 7]
# False
# 5
# 1
# 3
# 3
# 2
# 4
# 0
# 7
# 1
# [0, 1, 1, 2, 3, 3, 4, 5, 7]
# False
# 2
# 0
# 4
# 8
# 1
# 2
# 5
# 1
# 3
# [0, 1, 1, 2, 2, 3, 4, 5, 8]
# False
# 1
# 3
# 1
# 5
# 3
# 3
# 2
# 3
# 5
# [1, 1, 2, 3, 3, 3, 3, 5, 5]
# False
# 5
# 7
# 6
# 2
# 4
# 0
# 2
# 1
# 1
# [0, 1, 1, 2, 2, 4, 5, 6, 7]
# False
# 2
# 2
# 4
# 3
# 3
# 1
# 1
# 1
# 4
# [1, 1, 1, 2, 2, 3, 3, 4, 4]
# False
# 2
# 0
# 2
# 6
# 0
# 8
# 5
# 0
# 5
# [0, 0, 0, 2, 2, 5, 5, 6, 8]
# False
# 0
# 2
# 4
# 5
# 7
# 5
# 1
# 3
# 3
# [0, 1, 2, 3, 3, 4, 5, 5, 7]
# False
# 6
# 2
# 1
# 2
# 0
# 3
# 1
# 3
# 4
# [0, 1, 1, 2, 2, 3, 3, 4, 6]
# False
# 5
# 2
# 5
# 5
# 5
# 5
# 2
# 0
# 3
# [0, 2, 2, 3, 5, 5, 5, 5, 5]
# False
# 1
# 5
# 3
# 1
# 3
# 2
# 1
# 3
# 2
# ...
